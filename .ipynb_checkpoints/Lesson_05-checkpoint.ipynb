# %%
import numpy
import math 
from matplotlib import pyplot 
# %matplotlib inline

# %%
N = 500
x_start, x_end = -2.0,2.0
y_start, y_end = -.50,.50
x = numpy.linspace(x_start,x_end,N)
y = numpy.linspace(y_start,y_end,N)
X,Y = numpy.meshgrid(x,y)

# %%
N_v = 101
strength = 10
gamma = strength*numpy.ones(N_v)
x_vortex , y_vortex = numpy.linspace(x_start,x_end,N_v) , numpy.zeros(N_v)
a  = x_vortex[1] - x_vortex[0]

# %%
size = 15
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.xlim(x_start, x_end)
pyplot.ylim(y_start, y_end)
pyplot.scatter(x_vortex, y_vortex, color='#CD2305', s=80, marker='o');

# %%
def get_velocity_vortex(strength,xv,yv,X,Y):
    
    u = + strength/(2*math.pi)*(Y-yv)/((X-xv)**2+(Y-yv)**2) 
    v = - strength/(2*math.pi)*(X-xv)/((X-xv)**2+(Y-yv)**2)
    
    return u,v

# %%
def get_stream_function_vortex(strength, xv , yv, X , Y):
    
    psi = strength/(4*numpy.pi)*numpy.log((X-xv)**2+(Y-yv)**2)
    
    return psi

# %%
u_ans,v_ans = numpy.zeros((N,N), dtype = float),numpy.zeros((N,N), dtype = float)
psi_ans = numpy.zeros((N,N), dtype = float)

for i in range(N_v):

    
    u_temp,v_temp = get_velocity_vortex(gamma[i],x_vortex[i],y_vortex[i],X,Y)
    psi_temp = get_stream_function_vortex(gamma[i],x_vortex[i],y_vortex[i],X,Y)
    
    u_ans = u_ans + u_temp 
    v_ans = v_ans + v_temp
    psi_ans = psi_ans + psi_temp

# %%
size = 15
pyplot.figure(figsize=(size, size/3))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.xlim(.06*x_start, .06*x_end)
pyplot.ylim(.25*y_start, .25*y_end)
pyplot.streamplot(X, Y, u_ans, v_ans, density=20, linewidth=1, arrowsize=1, arrowstyle='->')
pyplot.scatter(x_vortex, y_vortex, color='#CD2305', s=80, marker='o');

# %% [markdown]
# # Infinite

# %%
u_inf = (strength/(2*a))*numpy.sinh(2*math.pi*Y/a)/(numpy.cosh(2*math.pi*Y/a)-numpy.cos(2*math.pi*X/a))  
v_inf =-(strength/(2*a))*numpy.sin(2*math.pi*X/a)/(numpy.cosh(2*math.pi*Y/a)-numpy.cos(2*math.pi*X/a))

# %%
size = 15
pyplot.figure(figsize=(size, size/3))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.xlim(.06*x_start, .06*x_end)
pyplot.ylim(.25*y_start, .25*y_end)
pyplot.streamplot(X, Y, u_inf, v_inf, density=15, linewidth=1, arrowsize=1, arrowstyle='->')
pyplot.scatter(x_vortex, y_vortex, color='#CD2305', s=80, marker='o');

# %% [markdown]
# # Done

# %%
# ?pyplot.streamplot
